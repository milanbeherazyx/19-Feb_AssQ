# %%
"""
Q1. What is Flask Framework? What are the advantages of Flask Framework?


Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999
Attach the screenshot of the output in Jupyter Notebook.
Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.
"""
# Out:
# '\nQ1. What is Flask Framework? What are the advantages of Flask Framework?\nQ2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in\nJupyter Notebook.\nQ3. What is App routing in Flask? Why do we use app routes?\nQ4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”\nroute to show the following details:\nCompany Name: ABC Corporation\nLocation: India\nContact Detail: 999-999-9999\nAttach the screenshot of the output in Jupyter Notebook.\nQ5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the\nurl_for() function.\n'

# %%
"""
Flask Framework is a Python-based micro web framework used for developing web applications. Flask is lightweight, modular, and flexible, allowing developers to build web applications quickly and easily. Some advantages of Flask Framework are:

Easy to set up and use
Lightweight and simple, making it ideal for small to medium-sized applications
Modular, allowing developers to add only the necessary features to their applications
Extensible, with a wide range of extensions available for various functionalities such as database integration, authentication, and caching
Integrated development server, which allows developers to test their applications quickly and easily without setting up a separate server.
"""
# Out:
# '\nFlask Framework is a Python-based micro web framework used for developing web applications. Flask is lightweight, modular, and flexible, allowing developers to build web applications quickly and easily. Some advantages of Flask Framework are:\n\nEasy to set up and use\nLightweight and simple, making it ideal for small to medium-sized applications\nModular, allowing developers to add only the necessary features to their applications\nExtensible, with a wide range of extensions available for various functionalities such as database integration, authentication, and caching\nIntegrated development server, which allows developers to test their applications quickly and easily without setting up a separate server.\n'

# %%
"""
Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.
"""
# Out:
# '\nQ2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.\n'

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello_world():
    return 'Hello World!!'

if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Q2.png](attachment:773356a8-3b4c-4e2b-8bdb-f86108d81019.png)

# %%
"""
Q3. What is App routing in Flask? Why do we use app routes?
"""
# Out:
# '\nQ3. What is App routing in Flask? Why do we use app routes?\n'

# %%
"""
App routing in Flask is the process of mapping URLs to Python functions in a Flask application. 
Flask uses the @app.route() decorator to define routes for different URLs. 
When a user requests a URL, Flask maps that URL to the appropriate Python function and returns the output of that function as the response. 
We use app routes to handle different URLs and to serve different pages or content based on the requested URL.
"""
# Out:
# '\nApp routing in Flask is the process of mapping URLs to Python functions in a Flask application. \nFlask uses the @app.route() decorator to define routes for different URLs. \nWhen a user requests a URL, Flask maps that URL to the appropriate Python function and returns the output of that function as the response. \nWe use app routes to handle different URLs and to serve different pages or content based on the requested URL.\n'

# %%
"""
Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a "/"
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999
"""
# Out:
# '\nQ4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a "/"\nroute to show the following details:\nCompany Name: ABC Corporation\nLocation: India\nContact Detail: 999-999-9999\n'

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def home():
    return '<h1>Company Name: ABC Corporation</h1><br><h2>Location: India</h2><br><h3>Contact Detail: 999-999-9999</h3>'

if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Q4.png](attachment:4030009b-f8d1-4863-ad2e-e39076475180.png)

# %%
"""
Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
"""
# Out:
# '\nQ5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.\n'

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/user/<username>')
def show_user_profile(username):
    return 'User %s' % username

@app.route('/post/<int:post_id>')
def show_post(post_id):
    return 'Post %d' % post_id

@app.route('/')
def index():
    return '<a href="%s">Profile</a><br><a href="%s">Post</a>' % (url_for('show_user_profile', username='john'), url_for('show_post', post_id=1))

if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Q5.1.png](attachment:ae7245b0-dc24-41b8-9fdd-104c30e19935.png)

# %% [markdown]
# ![Q5.2.png](attachment:e007e07c-cf1a-44c0-b987-2899b277055f.png)

# %% [markdown]
# ![Q5.3.png](attachment:541d40c0-47ab-438d-8b61-518a8a975329.png)
